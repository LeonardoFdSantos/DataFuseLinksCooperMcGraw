# %%
elosMax = {
    '1H': {
        'a': 11.5834,
        'b': -7.7159,
        'c': 2.2435,
        'd': -0.4141,
        'e': 0.0293,
        'IoIn': 1,
    },
    '2H': {
        'a': 15.3612,
        'b': -11.3048,
        'c': 3.7855,
        'd': -0.6767,
        'e': 0.0442,
        'IoIn': 2,
    },
    '3H': {
        'a': 16.6469,
        'b': -10.3608,
        'c': 2.8987,
        'd': -0.4844,
        'e': 0.0315,
        'IoIn': 3,
    },
    '5H': {
        'a': 33.5364,
        'b': -24.1389,
        'c': 7.0071,
        'd': -1.0167,
        'e': 0.0569,
        'IoIn': 5,
    },
    '8H': {
        'a': 137.5572,
        'b': -119.0117,
        'c': 38.2794,
        'd': -5.4440,
        'e': 0.2846,
        'IoIn': 8,
    },
    '6K': {
        'a': 181.2568,
        'b': -167.5711,
        'c': 57.6673,
        'd': -8.7672,
        'e': 0.4916,
        'IoIn': 6,
    },
    '8K': {
        'a': 201.6778,
        'b': -175.2376,
        'c': 56.8760,
        'd': -8.1725,
        'e': 0.4340,
        'IoIn': 8,
    },
    '10K': {
        'a': 251.8801,
        'b': -206.6378,
        'c': 63.3069,
        'd': -8.5810,
        'e': 0.4304,
        'IoIn': 10,
    },
    '12K': {
        'a': 294.2461,
        'b': -229.0340,
        'c': 66.6693,
        'd': -8.5945,
        'e': 0.4107,
        'IoIn': 12,
    },
    '15K': {
        'a': 346.4070,
        'b': -257.6697,
        'c': 71.6644,
        'd': -8.8225,
        'e': 0.4027,
        'IoIn': 15,
    },
    '20K': {
        'a': 382.4620,
        'b': -271.3985,
        'c': 72.1161,
        'd': -8.4924,
        'e': 0.3714,
        'IoIn': 20,
    },
    '25K': {
        'a': 469.9755,
        'b': -321.2512,
        'c': 82.1749,
        'd': -9.3092,
        'e': 0.3918,
        'IoIn': 25,
    },
    '30K': {
        'a': 516.7220,
        'b': -337.6034,
        'c': 82.5876,
        'd': -8.9522,
        'e': 0.3608,
        'IoIn': 30,
    },
    '40K': {
        'a': 672.1360,
        'b': -424.7867,
        'c': 100.3706,
        'd': -10.4950,
        'e': 0.4080,
        'IoIn': 40,
    },
    '50K': {
        'a': 691.3953,
        'b': -419.2300,
        'c': 95.1730,
        'd': -9.5735,
        'e': 0.3584,
        'IoIn': 50,
    },
    '65K': {
        'a': 841.8993,
        'b': -492.8148,
        'c': 107.9499,
        'd': -10.4731,
        'e': 0.3783,
        'IoIn': 65,
    },
    '80K': {
        'a': 881.1649,
        'b': -499.4578,
        'c': 106.0005,
        'd': -9.9685,
        'e': 0.3492,
        'IoIn': 80,
    },
    '100K': {
        'a': 1020.0325,
        'b': -554.4466,
        'c': 112.8674,
        'd': -10.1845,
        'e': 0.3425,
        'IoIn': 100,
    }
}


elosMin = {
    '1H': {
        'a': 11.6256,
        'b': -6.4698,
        'c': 1.3804,
        'd': -0.2041,
        'e': 0.0133,
        'IoIn': 1,
    },
    '2H': {
        'a': 14.6714,
        'b': -9.1330,
        'c': 2.5653,
        'd': -0.4144,
        'e': 0.0256,
        'IoIn': 2,
    },
    '3H': {
        'a': 16.3187,
        'b': -8.3597,
        'c': 1.7248,
        'd': -0.2310,
        'e': 0.0136,
        'IoIn': 3,
    },
    '5H': {
        'a': 30.5611,
        'b': -18.3646,
        'c': 4.2355,
        'd': -0.4978,
        'e': 0.0237,
        'IoIn': 5,
    },
    '8H': {
        'a': 138.7659,
        'b': -111.3549,
        'c': 33.2333,
        'd': -4.4002,
        'e': 0.2156,
        'IoIn': 8,
    },
    '6K': {
        'a': 192.9941,
        'b': -169.0384,
        'c': 55.2403,
        'd': -7.9961,
        'e': 0.4286,
        'IoIn': 6,
    },
    '8K': {
        'a': 232.6677,
        'b': -193.0379,
        'c': 59.8091,
        'd': -8.2061,
        'e': 0.4173,
        'IoIn': 8,
    },
    '10K': {
        'a': 287.7564,
        'b': -225.9500,
        'c': 66.2420,
        'd': -8.5945,
        'e': 0.4135,
        'IoIn': 10,
    },
    '12K': {
        'a': 334.4284,
        'b': -250.5401,
        'c': 70.1765,
        'd': -8.7063,
        'e': 0.4011,
        'IoIn': 12,
    },
    '15K': {
        'a': 371.4044,
        'b': -265.3945,
        'c': 70.9172,
        'd': -8.3938,
        'e': 0.3691,
        'IoIn': 15,
    },
    '20K': {
        'a': 438.8777,
        'b': -299.2860,
        'c': 76.3801,
        'd': -8.6400,
        'e': 0.3636,
        'IoIn': 20,
    },
    '25K': {
        'a': 491.9018,
        'b': -322.7019,
        'c': 79.2818,
        'd': -8.6364,
        'e': 0.3502,
        'IoIn': 25,
    },
    '30K': {
        'a': 549.9245,
        'b': -345.5217,
        'c': 81.3149,
        'd': -8.4872,
        'e': 0.3299,
        'IoIn': 30,
    },
    '40K': {
        'a': 652.1884,
        'b': -396.8930,
        'c': 90.4090,
        'd': -9.1277,
        'e': 0.3432,
        'IoIn': 40,
    },
    '50K': {
        'a': 712.2121,
        'b': -417.4489,
        'c': 91.6205,
        'd': -8.9153,
        'e': 0.3233,
        'IoIn': 50,
    },
    '65K': {
        'a': 813.6765,
        'b': -461.0754,
        'c': 97.8160,
        'd': -9.1979,
        'e': 0.3223,
        'IoIn': 65,
    },
    '80K': {
        'a': 970.6168,
        'b': -532.6923,
        'c': 109.4302,
        'd': -9.9635,
        'e': 0.3382,
        'IoIn': 80,
    },
    '100K': {
        'a': 1065.7914,
        'b': -563.6017,
        'c': 111.5874,
        'd': -9.7938,
        'e': 0.3206,
        'IoIn': 100,
    }
}

# %%
import math
import pandas as pd
import numpy as np
import warnings
from matplotlib import pyplot
from bokeh.plotting import figure, output_file, show
import plotly.graph_objects as go
import plotly.express as px
from scipy.optimize import curve_fit
warnings.filterwarnings("ignore", category=RuntimeWarning)

# %%
valores1h = pd.read_csv('FuseLink1h.csv');
valores2h = pd.read_csv('FuseLink2h.csv');
valores3h = pd.read_csv('FuseLink3h.csv');
valores5h = pd.read_csv('FuseLink5h.csv');
valores8h = pd.read_csv('FuseLink8h.csv');
valores6k = pd.read_csv('FuseLink6k.csv');
valores8k = pd.read_csv('FuseLink8k.csv');
valores10k = pd.read_csv('FuseLink10k.csv');
valores12k = pd.read_csv('FuseLink12k.csv');
valores15k = pd.read_csv('FuseLink15k.csv');
valores20k = pd.read_csv('FuseLink20k.csv');
valores25k = pd.read_csv('FuseLink25k.csv');
valores30k = pd.read_csv('FuseLink30k.csv');
valores40k = pd.read_csv('FuseLink40k.csv');
valores50k = pd.read_csv('FuseLink50k.csv');
valores65k = pd.read_csv('FuseLink65k.csv');
valores80k = pd.read_csv('FuseLink80k.csv');
valores100k = pd.read_csv('FuseLink100k.csv');

# %%
def objetivo(x, a, b, c, d, e):
    return a + (b * x) + (c * x**2) + (d * x**3) + (e * x**4)
